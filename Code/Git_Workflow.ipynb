# %%
import subprocess
import os

# Définir le chemin du dépôt
repo_path = r"C:\Users\Aubin\Documents\MANTIS"
os.chdir(repo_path)

# Fonction pull
def git_pull():
    subprocess.run(["git", "pull", "origin", "main", "--allow-unrelated-histories"])

# Fonction add/commit/push
def git_add_commit_push(message="Mise à jour du projet"):
    subprocess.run(["git", "add", "."])
    subprocess.run(["git", "commit", "-m", message])
    subprocess.run(["git", "push", "-u", "origin", "main"])

# %%
git_pull()  # récupérer les dernières modifications

# %%
git_add_commit_push("Ajout d'une nouvelle analyse")  # pousser tes modifications

# %%
# !git add Code/Git_Workflow.ipynb

# %%
# !git commit -m "Mise à jour de Biodiv_GBIF et ajout du notebook Git_Workflow"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'Aubin@DESKTOP-6KGQ0EC.(none)')

# %%
# !git config --global user.name "aubinnnormand"
# !git config --global user.email "aubin.nor@gm.com"
