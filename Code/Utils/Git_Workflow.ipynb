# %%
import subprocess
import os
from pathlib import Path
import ipynbname
import webbrowser

import subprocess
from pathlib import Path
import ipynbname

# Chemin du dépôt
repo_path = ipynbname.path().parent.parent.parent

def git_status():
    """Affiche l'état du repo."""
    result = subprocess.run(["git", "status", "--short"], cwd=repo_path, capture_output=True, text=True)
    if result.stdout.strip():
        print("⚠️ Modifications locales détectées :")
        print(result.stdout)
    else:
        print("✅ Pas de modifications locales.")

def git_update_with_confirmation():
    """Force la mise à jour depuis GitHub avec confirmation si des changements locaux existent."""
    git_status()
    
    answer = input("Voulez-vous écraser vos modifications locales et récupérer exactement la version GitHub ? [y/N] ").lower()
    if answer == 'y':
        # Récupérer la dernière version distante
        subprocess.run(["git", "fetch", "origin"], cwd=repo_path)
        # Forcer la version locale à correspondre au remote
        subprocess.run(["git", "reset", "--hard", "origin/main"], cwd=repo_path)
        print("✅ Repo mis à jour avec la version GitHub. Toutes les modifications locales ont été écrasées.")
    else:
        print("ℹ️ Opération annulée. Vos modifications locales sont conservées.")

def git_add_commit_push(message="Mise à jour automatique du projet"):
    """Ajoute, commit et push les modifications locales."""
    repo_path_local = Path(subprocess.run(
        ["git", "rev-parse", "--show-toplevel"], 
        capture_output=True, text=True
    ).stdout.strip())

    subprocess.run(["git", "add", "-A"], cwd=repo_path_local, check=True)
    subprocess.run(["git", "rm", "-r", "--cached", ".ipynb_checkpoints"], cwd=repo_path_local, stderr=subprocess.DEVNULL)
    
    result = subprocess.run(["git", "status", "--porcelain"], cwd=repo_path_local, capture_output=True, text=True)
    if result.stdout.strip():
        subprocess.run(["git", "commit", "-m", message], cwd=repo_path_local, check=True)
        subprocess.run(["git", "push", "-u", "origin", "main"], cwd=repo_path_local, check=True)
        print("✅ Modifications commit et push réussis.")
    else:
        print("ℹ️ Aucun changement à committer.")

# %%
repo_path
# !git config --list
# Out:
# diff.astextplain.textconv=astextplain
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# http.sslbackend=openssl
# http.sslcainfo=C:/Program Files/Git/mingw64/etc/ssl/certs/ca-bundle.crt
# core.autocrlf=true
# core.fscache=true
# core.symlinks=false
# pull.rebase=false
# init.defaultbranch=master
# credential.helper=store
# user.name=aubinnormand
# user.email=aubin.nor@gmail.com

# %%
git_update_with_confirmation()

# %%
git_add_commit_push("Work formatage")  # pousser tes modifications
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 git_add_commit_push("Work formatage")  # pousser tes modifications
#
# Cell In[1], line 44, in git_add_commit_push(message)
#      38 """Ajoute, commit et push les modifications locales."""
#      39 repo_path_local = Path(subprocess.run(
#      40     ["git", "rev-parse", "--show-toplevel"],
#      41     capture_output=True, text=True
#      42 ).stdout.strip())
# ---> 44 subprocess.run(["git", "add", "-A"], cwd=repo_path_local, check=True)
#      45 subprocess.run(["git", "rm", "-r", "--cached", ".ipynb_checkpoints"], cwd=repo_path_local, stderr=subprocess.DEVNULL)
#      47 result = subprocess.run(["git", "status", "--porcelain"], cwd=repo_path_local, capture_output=True, text=True)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:579, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     577     retcode = process.poll()
#     578     if check and retcode:
# --> 579         raise CalledProcessError(retcode, process.args,
#     580                                  output=stdout, stderr=stderr)
#     581 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['git', 'add', '-A']' returned non-zero exit status 128.

# %%
import os
os.getcwd()
# Out:
# 'D:\\MANTIS\\Code\\Utils'

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
webbrowser.open("https://github.com/aubinnormand/MANTIS")
